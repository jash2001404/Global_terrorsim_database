# %%
import pandas as pd 
import plotly.express as px 
import numpy
import plotly.io as pio
pio.renderers.default = "browser"
  
df = pd.read_csv('gtdmate.csv')
fig = px.scatter_geo(data_frame=df, lat="latitude",lon="longitude", 
                    color="targtype1_txt",
#                      hover_name="country_txt",
                     animation_frame="iyear",
                      labels={"country_txt":"Country","iyear":"Year",
                              "targtype1_txt":"Type of Target",
                              "attacktype1_txt":"Type of Attack",
                              "natlty1_txt":"Nationality of Victims"},
                     projection="natural earth"
                     # projection="orthographic"
                     )


button_layer_1_height = 1.01
fig.update_layout(
    updatemenus=[
        dict(
            buttons=list([
                    dict(
                        args=["color","targtype1_txt"],
                        label="Targets of Attack",
                        method="update"
                    ),dict(
                        args=["color","country_txt"],
                        label="Countries",
                        method="update"
                    ),dict(args=["color","targtype1_txt"],
                        label="Targets of Attack",
                        method="update"
                    ),dict(
                        args=["color","country_txt"],
                        label="Countries",
                        method="update"
                    ),dict(
                        args=["color","attacktype1_txt"],
                        label="Attack Type",
                        method="update"
                    ),dict(
                        args=["color","natlty1_txt"],
                        label="Nationality of Victims",
                        method="update"
                    )]),
            direction="down",
            pad={"r": 10, "t": 10},
            showactive=True,
            x=0.001,
            xanchor="left",
            y=button_layer_1_height,
            yanchor="top"
            )
    ]
)
fig.update_layout(title_text="Terror events over the years based on different variables ")

fig

# %%
import pandas as pd 
import plotly.express as px 
import numpy
import plotly.io as pio
pio.renderers.default = "browser"
  
df = pd.read_csv('gtdmate.csv')
fig = px.scatter_geo(data_frame=df, lat="latitude",lon="longitude", 
                    color="region_txt",
                     size=df["nkill"],size_max=100,
                     animation_frame="iyear",
                      labels={"country_txt":"Country","iyear":"Year",
                              "targtype1_txt":"Type of Target",
                              "attacktype1_txt":"Type of Attack",
                              "natlty1_txt":"Nationality of Victims","nkill":"Casualties","region_txt":"Region"},
                 projection="natural earth"
#                       projection="orthographic"
                     )
fig.update_layout(title_text="Casualities in terror events over the years")

fig

# %%
import pandas as pd
from plotly.offline import init_notebook_mode, iplot
init_notebook_mode(connected=True)

import cufflinks as cf
import plotly.io as pio
import plotly.graph_objects as go
import plotly.io as pio
pio.renderers.default = "browser"
df2= pd.read_csv("./reactterror.csv")

fig = go.Figure()

    
fig.add_trace(go.Scatter(x=list(df2.Year), y=list(df2.Fly),name='Fly on aeroplanes'))
fig.add_trace(go.Scatter(x=list(df2.Year), y=list(df2.skyscrapers),name='Go into skyscrapers'))
fig.add_trace(go.Scatter(x=list(df2.Year), y=list(df2.Attend),name='Go to crowded events'))
fig.add_trace(go.Scatter(x=list(df2.Year), y=list(df2.Travel),name='Travel Overseas'))
# Set title
fig.update_layout(title_text="More than a third in the US say they’re less willing to do certain activities because of terrorism")

# Add range slider
fig.update_layout(
    xaxis=dict(
        rangeselector=dict(
            buttons=list([
#                 dict(count=1,
#                      label="1m",
#                      step="month",
#                      stepmode="backward"),
                dict(count=12.5,
                     label="12.5y",
                     step="year",
                     stepmode="backward"),
#                 dict(count=1,
#                      label="YTD",
#                      step="year",
#                      stepmode="todate"),
                dict(count=7.5,
                     label="7.5y",
                     step="year",
                     stepmode="backward"),
                dict(step="all")
            ])
        ),
        rangeslider=dict(
            visible=True
        ),
        type="date"
    )
)

fig
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
